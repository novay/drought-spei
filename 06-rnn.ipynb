# %% [markdown]
# ### **Prediksi Suhu Rata-Rata menggunakan RNN**

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# **Prepare Data Testing**

# %%
test = pd.read_csv('data/test/apt-pranoto.csv', index_col='Tanggal', sep=";")
test.index = pd.to_datetime(test.index, format='%d-%m-%Y')
test = test.drop(['Tn', 'Tx', 'RH_avg', 'RR', 'ss', 'ff_x', 'ff_avg', 'ddd_car', 'ddd_x'], axis=1)
test = test.dropna()

print(len(test))
test.tail()
# Out:
# 2894
#             Tavg
# Tanggal
# 2020-12-27  27.2
# 2020-12-28  27.2
# 2020-12-29  26.2
# 2020-12-30  28.2
# 2020-12-31  26.6

# %% [markdown]
# #### **Train Test Split**
#
# Coba prediksi data sebulan kedepan (30 hari)

# %%
train_set = test.head(2894-30)
test_set = test.tail(30)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
train_scaled = scaler.fit_transform(train_set)
test_scaled = scaler.transform(test_set)

# %%
def next_batch(training_data, steps):
    rand_start = np.random.randint(0, len(training_data) - steps)
    y_batch = np.array(training_data[rand_start:rand_start + steps + 1]).reshape(1, steps + 1)
    return y_batch[:, :-1].reshape(-1, steps, 1), y_batch[:, 1:].reshape(-1, steps, 1)

# %%
num_inputs = 1
num_time_steps = 30
num_neurons = 100
num_outputs = 1
learning_rate = 0.001
num_train_iterations = 10001

# %% [markdown]
# Buat placeholder tensorflow X sebagai input, dan y sebagai outputnya

# %%
input_layer = tf.keras.layers.Input(shape=(num_time_steps, num_inputs))
cell = tf.keras.layers.SimpleRNN(units=num_neurons, activation=tf.nn.relu, return_sequences=True)(
    input_layer)
output_layer = tf.keras.layers.Dense(num_outputs)(cell)

# %%
model = tf.keras.Model(inputs=input_layer, outputs=output_layer)
model.compile(loss='mean_squared_error', optimizer=tf.keras.optimizers.legacy.SGD(learning_rate=learning_rate))

for iteration in range(num_train_iterations):
    X_batch, y_batch = next_batch(train_scaled, num_time_steps)
    model.train_on_batch(X_batch, y_batch)
    if iteration % 100 == 0:
        error = model.evaluate(X_batch, y_batch)
        print("iterasi ke -", iteration, "\t\tloss:", error)

model.save("models/prediksi_suhu_ratarata")
# Out:
# 1/1 [==============================] - 0s 163ms/step - loss: 0.1118
# iterasi ke - 0 		loss: 0.1118442565202713
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0163
# iterasi ke - 100 		loss: 0.016332918778061867
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0189
# iterasi ke - 200 		loss: 0.01894666627049446
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0102
# iterasi ke - 300 		loss: 0.010188460350036621
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0066
# iterasi ke - 400 		loss: 0.006568912882357836
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0155
# iterasi ke - 500 		loss: 0.015524250455200672
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0084
# iterasi ke - 600 		loss: 0.008351191878318787
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0113
# iterasi ke - 700 		loss: 0.01129123941063881
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0211
# iterasi ke - 800 		loss: 0.021144099533557892
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0131
# iterasi ke - 900 		loss: 0.01310575008392334
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0195
# iterasi ke - 1000 		loss: 0.019509712234139442
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0192
# iterasi ke - 1100 		loss: 0.019161652773618698
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0098
# iterasi ke - 1200 		loss: 0.009822726249694824
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0128
# iterasi ke - 1300 		loss: 0.012832803651690483
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0058
# iterasi ke - 1400 		loss: 0.0057798754423856735
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0129
# iterasi ke - 1500 		loss: 0.01293502189218998
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0101
# iterasi ke - 1600 		loss: 0.010121118277311325
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0096
# iterasi ke - 1700 		loss: 0.009568870067596436
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0111
# iterasi ke - 1800 		loss: 0.011126045137643814
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0113
# iterasi ke - 1900 		loss: 0.011313577182590961
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0083
# iterasi ke - 2000 		loss: 0.008279945701360703
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0149
# iterasi ke - 2100 		loss: 0.014903214760124683
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0127
# iterasi ke - 2200 		loss: 0.01273979339748621
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0286
# iterasi ke - 2300 		loss: 0.028555916622281075
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0108
# iterasi ke - 2400 		loss: 0.010766333900392056
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0243
# iterasi ke - 2500 		loss: 0.024268677458167076
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0112
# iterasi ke - 2600 		loss: 0.011222277767956257
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0073
# iterasi ke - 2700 		loss: 0.007335576228797436
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0094
# iterasi ke - 2800 		loss: 0.0093942666426301
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0058
# iterasi ke - 2900 		loss: 0.005770228337496519
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0149
# iterasi ke - 3000 		loss: 0.014894125983119011
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0094
# iterasi ke - 3100 		loss: 0.009353012777864933
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0156
# iterasi ke - 3200 		loss: 0.015604511834681034
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0098
# iterasi ke - 3300 		loss: 0.009835751727223396
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0112
# iterasi ke - 3400 		loss: 0.01116834208369255
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0080
# iterasi ke - 3500 		loss: 0.00803237035870552
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0166
# iterasi ke - 3600 		loss: 0.016626155003905296
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0113
# iterasi ke - 3700 		loss: 0.011274578049778938
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0115
# iterasi ke - 3800 		loss: 0.0115321334451437
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0079
# iterasi ke - 3900 		loss: 0.007904676720499992
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0134
# iterasi ke - 4000 		loss: 0.013426554389297962
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0097
# iterasi ke - 4100 		loss: 0.009716901928186417
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0093
# iterasi ke - 4200 		loss: 0.009264164604246616
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0070
# iterasi ke - 4300 		loss: 0.0070071411319077015
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0130
# iterasi ke - 4400 		loss: 0.013000094331800938
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0112
# iterasi ke - 4500 		loss: 0.01116466149687767
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0131
# iterasi ke - 4600 		loss: 0.013086142018437386
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0062
# iterasi ke - 4700 		loss: 0.006165100261569023
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0146
# iterasi ke - 4800 		loss: 0.014608260244131088
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0072
# iterasi ke - 4900 		loss: 0.0072164386510849
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0081
# iterasi ke - 5000 		loss: 0.008062148466706276
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0173
# iterasi ke - 5100 		loss: 0.0172695592045784
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0153
# iterasi ke - 5200 		loss: 0.01529720425605774
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0091
# iterasi ke - 5300 		loss: 0.009092146530747414
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0085
# iterasi ke - 5400 		loss: 0.00851836334913969
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0125
# iterasi ke - 5500 		loss: 0.012453708797693253
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0165
# iterasi ke - 5600 		loss: 0.016506081447005272
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0117
# iterasi ke - 5700 		loss: 0.0116814523935318
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0087
# iterasi ke - 5800 		loss: 0.008675974793732166
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0083
# iterasi ke - 5900 		loss: 0.008294055238366127
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0092
# iterasi ke - 6000 		loss: 0.0092274509370327
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0062
# iterasi ke - 6100 		loss: 0.0062071699649095535
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0149
# iterasi ke - 6200 		loss: 0.01489889994263649
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0077
# iterasi ke - 6300 		loss: 0.007679342292249203
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0058
# iterasi ke - 6400 		loss: 0.005789910908788443
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0093
# iterasi ke - 6500 		loss: 0.009294748306274414
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0200
# iterasi ke - 6600 		loss: 0.020008768886327744
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0146
# iterasi ke - 6700 		loss: 0.014581183902919292
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0112
# iterasi ke - 6800 		loss: 0.011226139031350613
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0088
# iterasi ke - 6900 		loss: 0.00883991364389658
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0072
# iterasi ke - 7000 		loss: 0.007236330304294825
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0054
# iterasi ke - 7100 		loss: 0.00539912935346365
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0119
# iterasi ke - 7200 		loss: 0.01186832319945097
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0110
# iterasi ke - 7300 		loss: 0.011041986756026745
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0052
# iterasi ke - 7400 		loss: 0.005208281800150871
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0132
# iterasi ke - 7500 		loss: 0.013223081827163696
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0086
# iterasi ke - 7600 		loss: 0.008647535927593708
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0088
# iterasi ke - 7700 		loss: 0.008849057368934155
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0080
# iterasi ke - 7800 		loss: 0.008008568547666073
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0086
# iterasi ke - 7900 		loss: 0.008551466278731823
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0078
# iterasi ke - 8000 		loss: 0.007753385230898857
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0159
# iterasi ke - 8100 		loss: 0.015858089551329613
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0057
# iterasi ke - 8200 		loss: 0.005704973824322224
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0096
# iterasi ke - 8300 		loss: 0.009624003432691097
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0105
# iterasi ke - 8400 		loss: 0.01046378817409277
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0121
# iterasi ke - 8500 		loss: 0.012142332270741463
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0137
# iterasi ke - 8600 		loss: 0.01370860543102026
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0071
# iterasi ke - 8700 		loss: 0.007081256248056889
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0140
# iterasi ke - 8800 		loss: 0.013974794186651707
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0072
# iterasi ke - 8900 		loss: 0.007205825764685869
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0098
# iterasi ke - 9000 		loss: 0.009800715371966362
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0070
# iterasi ke - 9100 		loss: 0.0070274160243570805
# 1/1 [==============================] - 0s 51ms/step - loss: 0.0049
# iterasi ke - 9200 		loss: 0.004857935477048159
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0121
# iterasi ke - 9300 		loss: 0.012111437506973743
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0094
# iterasi ke - 9400 		loss: 0.009369569830596447
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0098
# iterasi ke - 9500 		loss: 0.009771674871444702
# 1/1 [==============================] - 0s 52ms/step - loss: 0.0059
# iterasi ke - 9600 		loss: 0.005925952456891537
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0054
# iterasi ke - 9700 		loss: 0.005419191438704729
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0068
# iterasi ke - 9800 		loss: 0.0068220593966543674
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0109
# iterasi ke - 9900 		loss: 0.010910779237747192
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0209
# iterasi ke - 10000 		loss: 0.02092725969851017
# INFO:tensorflow:Assets written to: models/prediksi_suhu_ratarata/assets
# INFO:tensorflow:Assets written to: models/prediksi_suhu_ratarata/assets

# %%
model = tf.keras.models.load_model("models/prediksi_suhu_ratarata")
train_seed = np.array(train_scaled)

for iteration in range(30):
    X_batch = train_seed[-num_time_steps:].reshape(1, num_time_steps, 1)
    y_pred = model.predict(X_batch)
    train_seed = np.append(train_seed, y_pred[0, -1, 0])
# Out:
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step

# %%
train_seed
# Out:
# array([0.42528736, 0.36781609, 0.32183908, ..., 0.44797504, 0.44802976,
#        0.44808382])

# %%
results = scaler.inverse_transform(np.array(train_seed[:30]).reshape(num_time_steps, 1))
test_set['Prediksi'] = results
test_set
# Out:
# /var/folders/_w/v4htfwfd40ggzfmlgw22dk2m0000gn/T/ipykernel_59552/4124513893.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_set['Prediksi'] = results
#             Tavg  Prediksi
# Tanggal
# 2020-12-02  26.4      27.8
# 2020-12-03  28.0      27.3
# 2020-12-04  28.2      26.9
# 2020-12-05  29.6      27.2
# 2020-12-06  29.4      27.0
# 2020-12-07  28.8      24.8
# 2020-12-08  28.5      27.0
# 2020-12-09  29.4      26.3
# 2020-12-10  27.8      26.6
# 2020-12-11  28.3      26.1
# 2020-12-12  27.1      26.1
# 2020-12-13  27.3      27.8
# 2020-12-14  28.7      25.0
# 2020-12-15  27.5      27.7
# 2020-12-16  28.2      25.9
# 2020-12-17  27.6      28.1
# 2020-12-18  27.4      27.9
# 2020-12-19  27.0      26.3
# 2020-12-20  29.0      26.3
# 2020-12-21  27.5      27.5
# 2020-12-22  26.7      27.1
# 2020-12-23  27.4      27.5
# 2020-12-24  27.6      26.2
# 2020-12-25  26.0      27.5
# 2020-12-26  26.6      27.8
# 2020-12-27  27.2      27.6
# 2020-12-28  27.2      27.5
# 2020-12-29  26.2      27.1
# 2020-12-30  28.2      28.4
# 2020-12-31  26.6      28.9

# %%
test_set.plot()
# Out:
# <Axes: xlabel='Tanggal'>
